# %% [markdown]
# <a href="https://colab.research.google.com/github/suryansh9450/SD_Suryansh_0150/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %%
5*5
# Out:
# 25

# %%
x = 10

# %%
type(x)
# Out:
# int

# %%
x=10

# %%
y=5

# %%
x+y
# Out:
# 15

# %%
x-y
# Out:
# 5

# %%
x*y
# Out:
# 50

# %%
x/y
# Out:
# 2.0

# %%
type(y)
# Out:
# int

# %%
surya = 15

# %%
x+surya
# Out:
# 25

# %%
b=2.3

# %%
type(b)
# Out:
# float

# %%
c=20.33

# %%
type(c)
# Out:
# float

# %%
d = "surya"

# %%
type(d)
# Out:
# str

# %%
n=True

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1526/2794436645.py in <cell line: 0>()
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
False/True
# Out:
# 0.0

# %%
True*True
# Out:
# 1

# %%
True+True
# Out:
# 2
