# %% [markdown]
# <a href="https://colab.research.google.com/github/suryansh9450/SD_Suryansh_0150/blob/main/List2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l= [1,345,45,"sudh",True,5+7j,345.456]

# %%
l[5].real
# Out:
# 5.0

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
l[-1:-5:-2]
# Out:
# [345.456, True]

# %%
l[::2]
# Out:
# [1, 45, True, 345.456]

# %%
str = "suryansh"

# %%
list(str)+l
# Out:
# ['s',
#  'u',
#  'r',
#  'y',
#  'a',
#  'n',
#  's',
#  'h',
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456]

# %%
l1 =[3,4,5]

# %%
l+ l1
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 3, 4, 5]

# %%
l1*3
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
len(l)
# Out:
# 7

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5]

# %%
l.append(5)

# %%
str
# Out:
# 'suryansh'

# %%
l.extend("sudh")

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  5,
#  5,
#  5,
#  5,
#  's',
#  'u',
#  'd',
#  'h',
#  's',
#  'u',
#  'd',
#  'h']

# %%
l.extend([3,4,5])

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  5,
#  5,
#  5,
#  5,
#  's',
#  'u',
#  'd',
#  'h',
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5,
#  3,
#  4,
#  5]

# %%
l1.insert(1,"sudh")

# %%
l1
# Out:
# [3, 'sudh', 'sudh', 4, 5]

# %%
l1.pop(3)
# Out:
# 5

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  5,
#  5,
#  5,
#  5,
#  's',
#  'u',
#  'd',
#  'h',
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5,
#  3,
#  4,
#  5]

# %%
l.remove(3)

# %%
l1
# Out:
# [3, 'sudh', 'sudh']

# %%
l1.reverse()

# %%
l1
# Out:
# [3, 'sudh', 'sudh']

# %%
l2 = [45,23,90,0,3,4,5,6,7,8,9]

# %%
l2.sort()

# %%
l2
# Out:
# [0, 3, 4, 5, 6, 7, 8, 9, 23, 45, 90]

# %%
str = "suryansh"
str.replace("nsh","")
# Out:
# 'surya'

# %%
t = (2,3,4,'sudh',45.56,False,45+457j,[3,4,5])
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 8

# %%
t*(5)
# Out:
# (2,
#  3,
#  4,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5])

# %%
s1 ={}

# %%
type(s1)
# Out:
# dict

# %%
s2 ={2,3,4,55,67}
type(s2)
# Out:
# set

# %%
s3= {21,25,26,24,(45+45j),25,25,29}

# %%
s3
# Out:
# {(45+45j), 21, 24, 25, 26, 29}

# %%
s4  = {2,2,2,5,5,5,4,47,8,5,55,7,89,7,7,5,59,88}
s4
# Out:
# {2, 4, 5, 7, 8, 47, 55, 59, 88, 89}

# %%
l6 =[2,3,2,5,6,8,9,4,7,5,6,2,]

# %%
l6 = list(set(l6))
