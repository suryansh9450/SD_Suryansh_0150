# %% [markdown]
# <a href="https://colab.research.google.com/github/suryansh9450/SD_Suryansh_0150/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst = [1,2,3,4,True, 6+7j ,7,8,9,10]

# %%
lst[5].real
# Out:
# 6.0

# %%
lst[::2]
# Out:
# [1, 3, 5, 7, 9]

# %%
lst[::-1]
# Out:
# [10, 9, 8, 7, (6+7j), 5, 4, 3, 2, 1]

# %%
lst[-1:-5:-2]
# Out:
# [10, 8]

# %%
lst[1:6:-2]
# Out:
# []

# %%
lst[-1:-10:-8]
# Out:
# [6, 3]

# %%
lst.append(10)

# %%
print(lst)
# Out:
# suryansh

# %%
str = "suryansh"

# %%
lst[2],[3]
# Out:
# ('r', [3])

# %%
lst = [1,2,3,4,True, 6+7j ,7,8,9,10]

# %%
str="suryansh"
list(str) + lst
# Out:
# ['s', 'u', 'r', 'y', 'a', 'n', 's', 'h', 1, 2, 3, 4, True, (6+7j), 7, 8, 9, 10]

# %%
l = [1,345,45,'surya',(5+7j),345.456]

# %%
str = "suryansh"

# %%
str(l[4])[0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_556/3914801565.py in <cell line: 0>()
# ----> 1 str(l[4])[0:2]
#
# TypeError: 'str' object is not callable

# %%
l.insert(4,7)

# %%
name = input("Enter your name:")
# Out:
# Enter your name:suryansh

# %%
age = int(input("Enter your age:"))
# Out:
# Enter your age:20

# %%
name = input("Enter your name:")
age = int(input("Enter your age:"))
print("Name:",name)
print("Age:",age)
# Out:
# Enter your name:suryansh
# Enter your age:20
# Name: suryansh
# Age: 20

# %%
x = "10"
y = int(x)
print(y)
# Out:
# 10

# %%
x = "3.14"
y = float(x)
print(x)
# Out:
# 3.14

# %%
x = (1,2,3)
y = list(x)
print(y)
# Out:
# [1, 2, 3]

# %%
x=[1,2,3]
y =tuple(x)
print(y)
# Out:
# (1, 2, 3)

# %%
x = [1,2,3,3]
y  = set(x)
print(y)
# Out:
# {1, 2, 3}
