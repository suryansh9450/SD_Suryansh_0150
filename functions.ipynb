# %% [markdown]
# <a href="https://colab.research.google.com/github/suryansh9450/SD_Suryansh_0150/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calc(a,b,p):
  a = 10
  b = 20
  if p == "add":
    return a+b
  elif p == "sub":
    return a-b
  elif p == "mul":
    return a*b
  elif p == "div":
    return a/b
  else:
    return

# %%
card_details = {111,2456,222,3654}
user_details = {4655:5644,58841:65845}
print("choose widrawal")
print("check balance")
print("change password")
print("exit")
operation = int(input("enter your option:"))
if operation ==1:
  amt = int(input("enter your amount:"))
  pin = int(input("enter your pin no:"))
  for k,v in card_details.item():
    if pin == v:
# Out:
#   File "/tmp/ipykernel_2384/2177063787.py", line 14
#
#     ^
# SyntaxError: incomplete input

# %%
def deposit():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    money=int(input("Enter amount to be deposited: "))
    customer["Amount"] = customer["Amount"] + money
def withdrawal():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    money=int(input("Enter amount to be withdrawn: "))
    if customer["Amount"] < money:
      print("Not enough balance")
    else:
      customer["Amount"] = customer["Amount"] - money
      return customer["Amount"]
def amount():
  print(customer["Amount"])

def pin_change():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    npin = int(input("Enter new PIN: "))
    n2pin = int(input("Confirm PIN"))
    if npin != n2pin:
      print("Not same")
    else:
      print("PIN changed succesfully")

customer = {"Card number" : 1234 , "PIN" : 789 , "Amount" : 4500 }
cnum = int(input("Enter Card number: "))
if cnum != customer["Card number"]:
  print("Invalid Card Number")
else:
  service = int(input("Enter service:\n 1-DEPOSIT \n 2-WITHDRAWAL \n 3-PIN CHANGE \n 4-AMOUNT CHECK \n "))
  if service == 1:
    deposit()
  elif service == 2:
    print("new amount :" ,withdrawal())
  elif service == 3:
    pin_change()
  elif service == 4:
    amount()
  else:
    print("Invalid choice")
# Out:
# Enter Card number: 1234
# Enter service:
#  1-DEPOSIT
#  2-WITHDRAWAL
#  3-PIN CHANGE
#  4-AMOUNT CHECK
#  4500
# Invalid choice

# %%
Options = ["Balance", "Withdraw", "Change PIN", "Exit"]

print("----Welcome To ATM Services----")
print("Please Insert Your Card")
print("Your Card is Inserted")

if input("Please Enter Your Pin: ") == "1234":
    print("Your Pin is Accepted")
    for I in Options:
        print(I)

    SERVICES = int(input("Please Select Your Option: "))
    if SERVICES == 1:
        print("Your Balance is: 12")
    elif SERVICES == 2:
        WITHDRAW = int(input("Please Enter The Amount You Want To Withdraw: "))
        print(f"You Have Withdrawn: {WITHDRAW}")
    elif SERVICES == 3:
        NEW_PIN = input("Please Enter Your New Pin: ")
        print(f"Your Pin Has Been Changed To: {NEW_PIN}")
    elif SERVICES == 4:
        print("Thank You For Using Our Services")
    else:
        print("Invalid Option Selected")
else:
    print("Invalid Pin")
# Out:
# ----Welcome To ATM Services----
# Please Insert Your Card
# Your Card is Inserted
# Please Enter Your Pin: 1234
# Your Pin is Accepted
# Balance
# Withdraw
# Change PIN
# Exit
# Please Select Your Option: 1
# Your Balance is: 12

# %%
def wid():
  amount = int(input("Enter Amount: "))


  if amount <= 0:
    print("Invalid Amount")

  elif amount > accounts[card]["balance"]:
    print("Insufficient Funds")
    print("Balance:", accounts[card]["balance"])

  else:
    atm_cash = 50000

  if amount > atm_cash:
    print("ATM Out of Cash")

  else:
    accounts[card]["balance"] -= amount
    print("Please Collect Your Cash")
    print("Updated Balance:", accounts[card]["balance"])
def dep():
  amount = int(input("Enter Deposit Amount: "))

  if amount <= 0:
    print("Invalid Amount")

  else:
    accounts[card]["balance"] += amount
    print("Deposit Successful")
    print("Updated Balance:", accounts[card]["balance"])
def bal():
  print("Current Balance:", accounts[card]["balance"])


accounts = {
    "1234567890": {"pin": "1234", "balance": 5000},
    "9876543210": {"pin": "4321", "balance": 10000}
}

card = input("Enter Card Number: ")

if card in accounts:
    pin = input("Enter PIN: ")

    if pin == accounts[card]["pin"]:

        while True:
            print("\n----- ATM MENU -----")
            print("1. Withdraw")
            print("2. Deposit")
            print("3. Balance Inquiry")
            print("4. Exit")

            choice = input("Enter your choice: ")
            if choice == "1":
                wid()
            elif choice == "2":
                dep()
            elif choice == "3":
                bal()
            elif choice == "4":
                print("Card Ejected")
                print("Thank You!")
                break

            else:
                print("Invalid Choice")

            receipt = input("Print Receipt? (y/n): ")
            if receipt.lower() == "y":
                print("----- RECEIPT -----")
                print("Balance:", accounts[card]["balance"])

            again = input("Another Transaction? (y/n): ")
            if again.lower() != "y":
                print("Card Ejected")
                print("Thank You!")
                break

    else:
        print("Incorrect PIN")
        print("Card Ejected")

else:
    print("Invalid Card Number")
# Out:
# Enter Card Number: 1234
# Invalid Card Number
